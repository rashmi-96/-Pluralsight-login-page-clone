# %% [markdown]
# <a href="https://colab.research.google.com/github/rashmi-96/-Pluralsight-login-page-clone/blob/main/Module_02.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as nm
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('Predict_Covid_Tweet.csv')

# %%
data.head()
# Out:
#   created_at lang                                               text
# 0   4/4/2020   en  I'm still learning how to survive on my own. T...
# 1   4/4/2020   en  We all need to fight #COVID19.\nAnyone can get...
# 2   4/4/2020   en  Trump’s impeachment distracted him from prepar...
# 3   4/4/2020   en  @PIB_India @prasoonjoshi_ We will beat the corona
# 4   4/4/2020   en  2. Most African countries have poor healthcare...

# %% [markdown]
# Data Pre-Processing

# %%
keep_col = ['created_at','lang','text']
new_data = data[keep_col]
new_data.to_csv('updated_dataset.csv')

# %%
new_data.head()
# Out:
#   created_at lang                                               text
# 0   4/4/2020   en  I'm still learning how to survive on my own. T...
# 1   4/4/2020   en  We all need to fight #COVID19.\nAnyone can get...
# 2   4/4/2020   en  Trump’s impeachment distracted him from prepar...
# 3   4/4/2020   en  @PIB_India @prasoonjoshi_ We will beat the corona
# 4   4/4/2020   en  2. Most African countries have poor healthcare...

# %%
#remove non english
new_data = new_data[new_data["lang"].str.contains("en")== True]
